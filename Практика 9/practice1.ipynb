# %%
from matplotlib import pyplot as plt
import numpy as np 
import pandas as pd

# %%
def fun1():
    noize = np.random.random_sample((50))-0.5
    x = np.random.random()*1000
    mas = []
    for i, j in enumerate(noize):
        mas.append(np.sin(i/np.pi + x)+j/2)
    return mas
TS = []
for i in range(10):
    TS.append(fun1())

# %%
plt.plot(TS[0])

# %%
for i in range(10):
    plt.plot(TS[i])

# %%
def fun2():
    noize = np.random.random_sample((50))-0.5
    x = np.random.random()-0.5
    y = np.random.randint(15, 36)
    print(y)
    mas = []
    for i, j in enumerate(noize):
        mas.append( (-(i-y)**2 / 300 + 1.5)/2 + j)
    return mas
for i in range(10):
    TS.append(fun2())
# Out:
# 26
# 18
# 15
# 32
# 23
# 18
# 25
# 18
# 35
# 27

# %%
for i in range(10, 20):
    plt.plot(TS[i])

# %%
minl = 10
maxl = 30
r = 10*len(TS)
quality = 0.05

# %%
def gen_shapelets(tsi, l):
    return []

# %%
def dist(sub, Wil):
    return []

# %%
def eval_quality(Ds, sub):
    return []

# %%
for tsi in TS:
    shapelets = []
    for l in range(minl, maxl +1):
        Wil = gen_shapelets(tsi, l)
        for sub in Wil:
            Ds = dist(sub, Wil) 
            quality_sub = eval_quality(Ds, sub)
            shapelets.append(sub, quality_sub)
